# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df = pd.read_csv('../output_data/cities.csv')
df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations=df[['Lat', 'Lng']]
humidity=df['Humidity']

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=300,
                                 point_radius=3)

fig.add_layer(heat_layer)

fig
Figure(layout=FigureLayout(height='420px'))
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#extract cities in US
hotel_df = df.dropna()
hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng']].copy()
hotel_df = hotel_df.loc[hotel_df['Country']=="US"]
hotel_df['Hotel Name']=""

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key
}

for i, row in hotel_df.iterrows():
    lat = row['Lat']
    lng = row['Lng']
    params['location']=f"{lat}, {lng}"
    
    city = requests.get(base_url, params).json()
    
    try:
        hotel_df.loc[i, "Hotel Name"] = city["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

hotel_df
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
#                City Country    Lat     Lng  \
# 15           albany      US  42.65  -73.75
# 24           fallon      US  46.84 -105.12
# 35           bethel      US  60.79 -161.76
# 36          clinton      US  41.84  -90.19
# 47   port elizabeth      US  39.31  -74.98
# 50           kodiak      US  39.95  -94.76
# 73   virginia beach      US  36.85  -75.98
# 93          antioch      US  38.00 -121.81
# 102       ketchikan      US  55.34 -131.65
# 103           kapaa      US  22.08 -159.32
# 106            hilo      US  19.71 -155.08
# 110          lompoc      US  34.64 -120.46
# 121           sitka      US  37.17  -99.65
# 132   west wendover      US  40.74 -114.07
# 144       plainview      US  34.18 -101.71
# 157     charlestown      US  41.38  -71.64
# 166        brainerd      US  46.36  -94.20
# 230      moses lake      US  47.13 -119.28
# 260         pahrump      US  36.21 -115.98
# 289           union      US  47.36 -123.10
# 323          juneau      US  58.30 -134.42
# 324          sidney      US  47.72 -104.16
# 341         raymond      US  43.04  -71.18
# 348           avera      US  33.19  -82.53
# 375      ocean city      US  30.44  -86.61
# 377        muskegon      US  43.23  -86.25
# 386      north bend      US  43.41 -124.22
# 395   half moon bay      US  37.46 -122.43
# 406         wexford      US  40.63  -80.06
# 426          arroyo      US  41.39  -78.88
# 449   makakilo city      US  21.35 -158.09
# 456            nome      US  30.04  -94.42
# 457         lahaina      US  20.87 -156.68
# 462   pacific grove      US  36.62 -121.92
# 486        bismarck      US  46.81 -100.78
# 497        havelock      US  34.88  -76.90
# 498   traverse city      US  44.76  -85.62
# 512         natchez      US  31.56  -91.40
# 519   saint anthony      US  43.97 -111.68
#
#                                             Hotel Name
# 15                                       Hilton Albany
# 24
# 35                             Long House Hotel Bethel
# 36                     Regency Inn & Conference Center
# 47                                          HAMMER RUN
# 50
# 73                    Hilton Virginia Beach Oceanfront
# 93                Days Inn & Suites by Wyndham Antioch
# 102                                   Snows Cove Lodge
# 103             Sheraton Kauai Resort at Coconut Beach
# 106                                 Hilo Seaside Hotel
# 110                         Holiday Inn Express Lompoc
# 121
# 132                                   Motel 6 Wendover
# 144             Holiday Inn Express & Suites Plainview
# 157                              Charlestown Breachway
# 166       Holiday Inn Express & Suites Brainerd-Baxter
# 230                       Ramada by Wyndham Moses Lake
# 260                         Best Western Pahrump Oasis
# 289                            Alderbrook Resort & Spa
# 323          Baranof Downtown, BW Signature Collection
# 324                Holiday Inn Express & Suites Sidney
# 341                         Englewood Mobile Home Park
# 348
# 375  Fairfield Inn & Suites Fort Walton Beach - Egl...
# 377                             A Victory Inn & Suites
# 386                            Red Lion Hotel Coos Bay
# 395                    The Ritz-Carlton, Half Moon Bay
# 406                                        Econo Lodge
# 426                                Elk County Elk Farm
# 449                     Marriott's Ko Olina Beach Club
# 456                  Silver Spur Mobile Home & RV Park
# 457                        Lahaina Shores Beach Resort
# 462                                   Lovers Point Inn
# 486                  Ramkota Hotel & Conference Center
# 497            Holiday Inn Express and Suites Havelock
# 498                                    Bayshore Resort
# 512                       Hampton Inn & Suites Natchez
# 519                                    Three Bears Inn

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)


# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
